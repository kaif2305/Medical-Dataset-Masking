# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('2018_2019_data.csv', encoding= 'unicode_escape')


x = df.iloc[:, [2]]

# %%
d = df['Pressure [hPa]']

for i in d:
  x.interpolate(method="polynomial", order=2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a6d3c13eb7c2> in <module>
#       2
#       3 for i in d:
# ----> 4   x.interpolate(method="polynomial", order=2)
#       5
#       6
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10710         **kwargs,
#   10711     ) -> DataFrame | None:
# > 10712         return super().interpolate(
#   10713             method,
#   10714             axis,
#
# ...

# %%
x.to_csv('new.csv', index=True)
