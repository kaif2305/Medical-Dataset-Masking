# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

df = pd.read_csv('hospital.csv')
df
# Out:
#      patcnty1  dsch_yr race_grp1  Discharges  AnnotationCode AnnotationDesc  \
# 0     Alameda     2012     Aisan     27637.0             NaN            NaN
# 1     Alameda     2012     Black     28455.0             NaN            NaN
# 2     Alameda     2012  Hispanic     25162.0             NaN            NaN
# 3     Alameda     2012  American       467.0             NaN            NaN
# 4     Alameda     2012     Other      6796.0             NaN            NaN
# ...       ...      ...       ...         ...             ...            ...
# 2839     Yuba     2018  Hispanic      1566.0             NaN            NaN
# 2840     Yuba     2018  American        96.0             NaN            NaN
# 2841     Yuba     2018     Other       197.0             NaN            NaN
# 2842     Yuba     2018   Unknown        69.0             NaN            NaN
# 2843     Yuba     2018     White      6531.0             NaN            NaN
#
#       Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 2839         NaN         NaN         NaN
# 2840         NaN         NaN         NaN
# 2841         NaN         NaN         NaN
# 2842         NaN         NaN         NaN
# 2843         NaN         NaN         NaN
#
#                                                mdc_desc  Unnamed: 10  \
# 0                  NERVOUS SYSTEM, DISEASES & DISORDERS          NaN
# 1                             EYE, DISEASES & DISORDERS          NaN
# 2      EAR, NOSE, MOUTH, & THROAT, DISEASES & DISORDERS          NaN
# 3              RESPIRATORY SYSTEM, DISEASES & DISORDERS          NaN
# 4              CIRCULATORY SYSTEM, DISEASES & DISORDERS          NaN
# ...                                                 ...          ...
# 2839  FACTORS ON HEALTH STATUS & OTHER CONTACTS WITH...          NaN
# 2840                         MULTIPLE SIGNFICANT TRAUMA          NaN
# 2841            HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS          NaN
# 2842               NERVOUS SYSTEM, DISEASES & DISORDERS          NaN
# 2843                          EYE, DISEASES & DISORDERS          NaN
#
#       Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 2839          NaN          NaN          NaN          NaN          NaN
# 2840          NaN          NaN          NaN          NaN          NaN
# 2841          NaN          NaN          NaN          NaN          NaN
# 2842          NaN          NaN          NaN          NaN          NaN
# 2843          NaN          NaN          NaN          NaN          NaN
#
#        gender  Unnamed: 17  Unnamed: 18   w
# 0      Female          NaN          NaN NaN
# 1        Male          NaN          NaN NaN
# 2     Unknown          NaN          NaN NaN
# 3      Female          NaN          NaN NaN
# 4        Male          NaN          NaN NaN
# ...       ...          ...          ...  ..
# 2839  Unknown          NaN          NaN NaN
# 2840   Female          NaN          NaN NaN
# 2841     Male          NaN          NaN NaN
# 2842  Unknown          NaN          NaN NaN
# 2843   Female          NaN          NaN NaN
#
# [2844 rows x 20 columns]

# %%
import seaborn as sns
from matplotlib import pyplot
sns.countplot(df.gender)
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.gender
# Out:
# 0        Female
# 1          Male
# 2       Unknown
# 3        Female
# 4          Male
#          ...
# 2839    Unknown
# 2840     Female
# 2841       Male
# 2842    Unknown
# 2843     Female
# Name: gender, Length: 2844, dtype: object

# %%
import seaborn as sns
from matplotlib import pyplot

sns.countplot(df.race_grp1)
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(df.race_grp1)
# Out:
# 0          Aisan
# 1          Black
# 2       Hispanic
# 3       American
# 4          Other
#           ...
# 2839    Hispanic
# 2840    American
# 2841       Other
# 2842     Unknown
# 2843       White
# Name: race_grp1, Length: 2844, dtype: object

# %%
df['Stratify'] = df['gender'] + ", " + df['race_grp1']
(df['Stratify'].value_counts() / len(df)).sort_values(ascending=False)
# Out:
# Female, Aisan        0.056962
# Female, American     0.056962
# Male, Other          0.056259
# Male, Hispanic       0.056259
# Male, White          0.056259
# Male, Black          0.055556
# Female, White        0.055556
# Female, Other        0.054852
# Female, Unknown      0.054852
# Male, American       0.054852
# Female, Hispanic     0.054501
# Male, Unknown        0.054149
# Male, Aisan          0.053446
# Female, Black        0.053446
# Unknown, Hispanic    0.034107
# Unknown, Unknown     0.033755
# Unknown, White       0.033404
# Unknown, American    0.031997
# Unknown, Other       0.031294
# Unknown, Aisan       0.030942
# Unknown, Black       0.030591
# Name: Stratify, dtype: float64
