# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer

df1 = pd.read_csv('After_Scaling_hospital.csv')
df2 = pd.read_csv('binary.csv', names = ["mdc_desc"])

# %%
df1.drop('mdc_desc', inplace=True, axis=1)

# %%
result = pd.concat([df1, df2], axis=1)

# %%
result.to_csv('Final_dataset.csv', index=True)
